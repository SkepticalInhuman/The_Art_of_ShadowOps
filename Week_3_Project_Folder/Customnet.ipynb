# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, Dense, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
train_dir = 'C:/Users/USER/Downloads/1/real_vs_fake/real-vs-fake/train'
validation_dir = 'C:/Users/USER/Downloads/1/real_vs_fake/real-vs-fake/valid'
test_dir = 'C:/Users/USER/Downloads/1/real_vs_fake/real-vs-fake/test'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 100000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj, name=None):
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3)
    
    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5)
    
    pool_proj = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)
    
    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=-1, name=name)
    
    return output

# %%
def custom_net(input_shape):
    inputs = Input(shape=input_shape)
    
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(inputs)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    x = Conv2D(64, (1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    x = inception_module(x, 64, 96, 128, 16, 32, 32, name='inception_3a')
    x = inception_module(x, 128, 128, 192, 32, 96, 64, name='inception_3b')
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    x = inception_module(x, 192, 96, 208, 16, 48, 64, name='inception_4a')
    x = inception_module(x, 160, 112, 224, 24, 64, 64, name='inception_4b')
    x = inception_module(x, 128, 128, 256, 24, 64, 64, name='inception_4c')
    x = inception_module(x, 112, 144, 288, 32, 64, 64, name='inception_4d')
    x = inception_module(x, 256, 160, 320, 32, 128, 128, name='inception_4e')
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    
    x = inception_module(x, 256, 160, 320, 32, 128, 128, name='inception_5a')
    x = inception_module(x, 384, 192, 384, 48, 128, 128, name='inception_5b')
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)
        
    model = Model(inputs, predictions)
    return model

# %%
input_shape = (224, 224, 3)
model = custom_net(input_shape)
model.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_114 (Conv2D)         (None, 112, 112, 64)         9472      ['input_3[0][0]']
#
#  max_pooling2d_26 (MaxPooli  (None, 56, 56, 64)           0         ['conv2d_114[0][0]']
#  ng2D)
#
#  conv2d_115 (Conv2D)         (None, 56, 56, 64)           4160      ['max_pooling2d_26[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 56, 56, 192)          110784    ['conv2d_115[0][0]']
#
#  max_pooling2d_27 (MaxPooli  (None, 28, 28, 192)          0         ['conv2d_116[0][0]']
#  ng2D)
#
#  conv2d_118 (Conv2D)         (None, 28, 28, 96)           18528     ['max_pooling2d_27[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 28, 28, 16)           3088      ['max_pooling2d_27[0][0]']
#
#  max_pooling2d_28 (MaxPooli  (None, 28, 28, 192)          0         ['max_pooling2d_27[0][0]']
#  ng2D)
#
#  conv2d_117 (Conv2D)         (None, 28, 28, 64)           12352     ['max_pooling2d_27[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 28, 28, 128)          110720    ['conv2d_118[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 28, 28, 32)           12832     ['conv2d_120[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 28, 28, 32)           6176      ['max_pooling2d_28[0][0]']
#
#  inception_3a (Concatenate)  (None, 28, 28, 256)          0         ['conv2d_117[0][0]',
#                                                                      'conv2d_119[0][0]',
#                                                                      'conv2d_121[0][0]',
#                                                                      'conv2d_122[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 28, 28, 128)          32896     ['inception_3a[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 28, 28, 32)           8224      ['inception_3a[0][0]']
#
#  max_pooling2d_29 (MaxPooli  (None, 28, 28, 256)          0         ['inception_3a[0][0]']
#  ng2D)
#
#  conv2d_123 (Conv2D)         (None, 28, 28, 128)          32896     ['inception_3a[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 28, 28, 192)          221376    ['conv2d_124[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 28, 28, 96)           76896     ['conv2d_126[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 28, 28, 64)           16448     ['max_pooling2d_29[0][0]']
#
#  inception_3b (Concatenate)  (None, 28, 28, 480)          0         ['conv2d_123[0][0]',
#                                                                      'conv2d_125[0][0]',
#                                                                      'conv2d_127[0][0]',
#                                                                      'conv2d_128[0][0]']
#
#  max_pooling2d_30 (MaxPooli  (None, 14, 14, 480)          0         ['inception_3b[0][0]']
#  ng2D)
#
#  conv2d_130 (Conv2D)         (None, 14, 14, 96)           46176     ['max_pooling2d_30[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 14, 14, 16)           7696      ['max_pooling2d_30[0][0]']
#
#  max_pooling2d_31 (MaxPooli  (None, 14, 14, 480)          0         ['max_pooling2d_30[0][0]']
#  ng2D)
#
#  conv2d_129 (Conv2D)         (None, 14, 14, 192)          92352     ['max_pooling2d_30[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 14, 14, 208)          179920    ['conv2d_130[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 14, 14, 48)           19248     ['conv2d_132[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 14, 14, 64)           30784     ['max_pooling2d_31[0][0]']
#
#  inception_4a (Concatenate)  (None, 14, 14, 512)          0         ['conv2d_129[0][0]',
#                                                                      'conv2d_131[0][0]',
#                                                                      'conv2d_133[0][0]',
#                                                                      'conv2d_134[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 14, 14, 112)          57456     ['inception_4a[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 14, 14, 24)           12312     ['inception_4a[0][0]']
#
#  max_pooling2d_32 (MaxPooli  (None, 14, 14, 512)          0         ['inception_4a[0][0]']
#  ng2D)
#
#  conv2d_135 (Conv2D)         (None, 14, 14, 160)          82080     ['inception_4a[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 14, 14, 224)          226016    ['conv2d_136[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 14, 14, 64)           38464     ['conv2d_138[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 14, 14, 64)           32832     ['max_pooling2d_32[0][0]']
#
#  inception_4b (Concatenate)  (None, 14, 14, 512)          0         ['conv2d_135[0][0]',
#                                                                      'conv2d_137[0][0]',
#                                                                      'conv2d_139[0][0]',
#                                                                      'conv2d_140[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 14, 14, 128)          65664     ['inception_4b[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 14, 14, 24)           12312     ['inception_4b[0][0]']
#
#  max_pooling2d_33 (MaxPooli  (None, 14, 14, 512)          0         ['inception_4b[0][0]']
#  ng2D)
#
#  conv2d_141 (Conv2D)         (None, 14, 14, 128)          65664     ['inception_4b[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 14, 14, 256)          295168    ['conv2d_142[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 14, 14, 64)           38464     ['conv2d_144[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 14, 14, 64)           32832     ['max_pooling2d_33[0][0]']
#
#  inception_4c (Concatenate)  (None, 14, 14, 512)          0         ['conv2d_141[0][0]',
#                                                                      'conv2d_143[0][0]',
#                                                                      'conv2d_145[0][0]',
#                                                                      'conv2d_146[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 14, 14, 144)          73872     ['inception_4c[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 14, 14, 32)           16416     ['inception_4c[0][0]']
#
#  max_pooling2d_34 (MaxPooli  (None, 14, 14, 512)          0         ['inception_4c[0][0]']
#  ng2D)
#
#  conv2d_147 (Conv2D)         (None, 14, 14, 112)          57456     ['inception_4c[0][0]']
#
#  conv2d_149 (Conv2D)         (None, 14, 14, 288)          373536    ['conv2d_148[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 14, 14, 64)           51264     ['conv2d_150[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 14, 14, 64)           32832     ['max_pooling2d_34[0][0]']
#
#  inception_4d (Concatenate)  (None, 14, 14, 528)          0         ['conv2d_147[0][0]',
#                                                                      'conv2d_149[0][0]',
#                                                                      'conv2d_151[0][0]',
#                                                                      'conv2d_152[0][0]']
#
#  conv2d_154 (Conv2D)         (None, 14, 14, 160)          84640     ['inception_4d[0][0]']
#
#  conv2d_156 (Conv2D)         (None, 14, 14, 32)           16928     ['inception_4d[0][0]']
#
#  max_pooling2d_35 (MaxPooli  (None, 14, 14, 528)          0         ['inception_4d[0][0]']
#  ng2D)
#
#  conv2d_153 (Conv2D)         (None, 14, 14, 256)          135424    ['inception_4d[0][0]']
#
#  conv2d_155 (Conv2D)         (None, 14, 14, 320)          461120    ['conv2d_154[0][0]']
#
#  conv2d_157 (Conv2D)         (None, 14, 14, 128)          102528    ['conv2d_156[0][0]']
#
#  conv2d_158 (Conv2D)         (None, 14, 14, 128)          67712     ['max_pooling2d_35[0][0]']
#
#  inception_4e (Concatenate)  (None, 14, 14, 832)          0         ['conv2d_153[0][0]',
#                                                                      'conv2d_155[0][0]',
#                                                                      'conv2d_157[0][0]',
#                                                                      'conv2d_158[0][0]']
#
#  max_pooling2d_36 (MaxPooli  (None, 7, 7, 832)            0         ['inception_4e[0][0]']
#  ng2D)
#
#  conv2d_160 (Conv2D)         (None, 7, 7, 160)            133280    ['max_pooling2d_36[0][0]']
#
#  conv2d_162 (Conv2D)         (None, 7, 7, 32)             26656     ['max_pooling2d_36[0][0]']
#
#  max_pooling2d_37 (MaxPooli  (None, 7, 7, 832)            0         ['max_pooling2d_36[0][0]']
#  ng2D)
#
#  conv2d_159 (Conv2D)         (None, 7, 7, 256)            213248    ['max_pooling2d_36[0][0]']
#
#  conv2d_161 (Conv2D)         (None, 7, 7, 320)            461120    ['conv2d_160[0][0]']
#
#  conv2d_163 (Conv2D)         (None, 7, 7, 128)            102528    ['conv2d_162[0][0]']
#
#  conv2d_164 (Conv2D)         (None, 7, 7, 128)            106624    ['max_pooling2d_37[0][0]']
#
#  inception_5a (Concatenate)  (None, 7, 7, 832)            0         ['conv2d_159[0][0]',
#                                                                      'conv2d_161[0][0]',
#                                                                      'conv2d_163[0][0]',
#                                                                      'conv2d_164[0][0]']
#
#  conv2d_166 (Conv2D)         (None, 7, 7, 192)            159936    ['inception_5a[0][0]']
#
#  conv2d_168 (Conv2D)         (None, 7, 7, 48)             39984     ['inception_5a[0][0]']
#
#  max_pooling2d_38 (MaxPooli  (None, 7, 7, 832)            0         ['inception_5a[0][0]']
#  ng2D)
#
#  conv2d_165 (Conv2D)         (None, 7, 7, 384)            319872    ['inception_5a[0][0]']
#
#  conv2d_167 (Conv2D)         (None, 7, 7, 384)            663936    ['conv2d_166[0][0]']
#
#  conv2d_169 (Conv2D)         (None, 7, 7, 128)            153728    ['conv2d_168[0][0]']
#
#  conv2d_170 (Conv2D)         (None, 7, 7, 128)            106624    ['max_pooling2d_38[0][0]']
#
#  inception_5b (Concatenate)  (None, 7, 7, 1024)           0         ['conv2d_165[0][0]',
#                                                                      'conv2d_167[0][0]',
#                                                                      'conv2d_169[0][0]',
#                                                                      'conv2d_170[0][0]']
#
#  global_average_pooling2d_2  (None, 1024)                 0         ['inception_5b[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 512)                  524800    ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dropout_2 (Dropout)         (None, 512)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1)                    513       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 6498865 (24.79 MB)
# Trainable params: 6498865 (24.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=1
)
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f'Test accuracy: {test_acc:.2f}')

model.save('C:/Users/USER/OneDrive/Desktop/soc/assignment_1_week_3/CustomCNN_real_fake_classifier_1.h5')
# Out:
# 3125/3125 [==============================] - 4669s 1s/step - loss: 0.6936 - accuracy: 0.4967 - val_loss: 0.6932 - val_accuracy: 0.5000
# 625/625 [==============================] - 290s 464ms/step - loss: 0.6932 - accuracy: 0.5000
# Test accuracy: 0.50
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
